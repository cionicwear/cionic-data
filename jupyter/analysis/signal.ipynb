# %% [markdown]
# # Signal
#
# notebook for exploring emg signal quality
#
# there are three ways to select an npz to analyze
#
# 1. specifying the local path
# 2. using the upload widget
# 3. running from the [Runner Notebook](runner.ipynb)

# %%
import json
import logging

import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
from ipywidgets import Layout, interact_manual

from cionic import api, segmenter, tools, triggers

# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Parameters
#
#
# These parameters will be overridden when this notebook is used with the runner
#
# ```
# npzpath     path on your local filesystem to find the recording or path
#             or path on the local filesystem to store the recording if download set
#
# download    xid of collection to download
#
# tokenpath   path to auth token if download is set
#
# ```

# %%
# param

npzpath = None
download = None
tokenpath = None
datapath = None

# %%
if datapath:
    api.auth(tokenpath=tokenpath)
    collection_data = api.get_cionic(datapath)
    print(json.dumps(collection_data.get("meta", {}).get("sensor_stats"), indent=4))

# %%
if download:
    api.auth(tokenpath=tokenpath)
    api.download_npz(npzpath, download)

try:
    npz = np.load(npzpath)
except FileNotFoundError:
    logging.error(f"npzpath [{npzpath}] not found")

if 'position' in npz['segments'].dtype.names:
    print(f"Positions: {set(npz['segments']['position'])}")

if 'stream' in npz['segments'].dtype.names:
    print(f"Stream: {set(npz['segments']['stream'])}")

# %% [markdown]
# ## Interface
#
# The following elements can be edited via the interface
#
# 1. which stream to examine
# 2. which filter to run on the signal
# 3. the cutoff frequency of that filter
# 4. window size for rms
# 5. fft or cdf

# %%
emg_filter_butter = {
    'filter': tools.butter_highpass_filter,
    'filter_order': 5,
}

emg_filter_fir = {
    'filter': tools.fir_filter,
    'taps_n': 63,
}

emg_filter_none = {'filter': None}

filters = {'off': emg_filter_none, 'butter': emg_filter_butter, 'fir': emg_filter_fir}

streams = [
    x
    for x in set(npz['segments']['stream'])
    if not x.startswith('shtp_')  # shtp_ streams should be redundant
    and x not in ['frsp', 'regs', 'charge']  # register streams
]
regs_dict = tools.stream_regs(npz)
data_dict, times, components = tools.stream_data(npz, streams=streams, degrees=False)

# Add stims
stim_streams = triggers.get_action_muscles(npz)
components.extend(stim_streams)

boundaries = segmenter.load_boundary_times(npz)
# construct dictionary keyed on "<label> <segment>"
gwlabels = {f"{b['label']} {b['segment']}": b for b in boundaries}
lastlabel = 'ALL'
dataLabels = list(gwlabels.keys())
dataLabels.sort(key=lambda name: int(name.split()[1]))
labels = [lastlabel] + dataLabels

w = '500px'
sliderLayout = Layout(width=w)
dropdownLayout = Layout(width=w, height='200px')

sp = widgets.SelectMultiple(
    options=components, description="streams", layout=dropdownLayout
)
rs = widgets.FloatRangeSlider(
    min=times[0],
    max=times[1],
    value=times,
    continuous_update=False,
    description="times",
    layout=sliderLayout,
)
fd = widgets.Dropdown(options=filters.keys(), description="filter")
rt = widgets.BoundedIntText(value=300, min=50, max=200000, step=50)
ct = widgets.BoundedIntText(value=10, min=0, max=150, step=5)
a1 = widgets.BoundedIntText(
    value=1, min=0, max=100000, step=1000, description="axis 1 scale"
)
a2 = widgets.BoundedIntText(
    value=10000, min=0, max=100000, step=1000, description="axis 2 scale"
)
# Create SelectMultiple widget for labels
lb = widgets.SelectMultiple(
    options=labels, value=['ALL'], description="labels", layout=dropdownLayout
)
title = widgets.Text(
    value='', placeholder='Enter title here', description='plot title:', disabled=False
)
xlabel = widgets.Text(
    value='',
    placeholder='Enter xlabel here',
    description='x-axis label:',
    disabled=False,
)
ylabel = widgets.Text(
    value='',
    placeholder='Enter ylabel here',
    description='y-axis label:',
    disabled=False,
)
color = widgets.Text(
    value='',
    placeholder='This will override plot colors.',
    description='plot color:',
    disabled=False,
)
ylim_min = widgets.FloatText(value=0, description='ylim min', disabled=False)
ylim_max = widgets.FloatText(value=0, description='ylim max', disabled=False)
plot_same = widgets.Checkbox(value=False, description='Same Plot?')
ncols = widgets.IntText(value=1, description='# columns', disabled=False)
legend_loc = widgets.Dropdown(
    options=[
        'best',
        'upper right',
        'upper left',
        'lower right',
        'lower left',
        'upper center',
        'lower center',
    ],
    description="legend location",
)
plot_sharex = widgets.Checkbox(value=True, description='Share x?')
show_filter_plots = widgets.Checkbox(value=False, description='Show RMS/filter plots')


@interact_manual
def show_emg(
    stream=sp,
    times=rs,
    label=lb,
    style=['-', 'o'],
    filter_plots_toggle=show_filter_plots,
    filt=fd,
    cutoff=ct,
    rms=rt,
    fft=['db', 'cdf'],
    a1_scale=a1,
    a2_scale=a2,
    plot_title=title,
    plot_xlabel=xlabel,
    plot_ylabel=ylabel,
    plot_color=color,
    plot_min=ylim_min,
    plot_max=ylim_max,
    legend_location=legend_loc,
    plot_on_same=plot_same,
    sharex=plot_sharex,
    plot_ncols=ncols,
):
    # Helper function to format subplot axes
    def format_subplot(ax):
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.set_xlabel(
            plot_xlabel if plot_xlabel else "elapsed_s", fontsize=14, fontweight='bold'
        )
        ax.set_ylabel(plot_ylabel, fontsize=14, fontweight='bold')
        if ylim_min.value != 0 or ylim_max.value != 0:
            ax.set_ylim([ylim_min.value, ylim_max.value])

    # Setup
    plt.close('all')
    fil = filters[filt]
    fil['cutoff_freq'] = cutoff
    (actions, stream) = triggers.check_for_action(stream)

    # Process label selections and compute time ranges
    selected_labels = label if isinstance(label, (list, tuple)) else [label]
    if 'ALL' in selected_labels or len(selected_labels) == 0:
        selected_labels = ['ALL']
        label_times = [(times[0], times[1])]
    else:
        label_times = [
            (
                gwlabels.get(lbl, {'start_s': times[0], 'end_s': times[1]})['start_s'],
                gwlabels.get(lbl, {'start_s': times[0], 'end_s': times[1]})['end_s'],
            )
            for lbl in selected_labels
        ]

    # Compute all signals for all labels upfront
    all_signals_data = [
        (
            lbl,
            start_t,
            end_t,
            *tools.compute_signals(
                data_dict,
                regs_dict,
                stream,
                (start_t, end_t),
                fil,
                rms,
                fft,
                [a1_scale, a2_scale],
            ),
        )
        for lbl, (start_t, end_t) in zip(selected_labels, label_times)
    ]

    # Extract first signals and legends for convenience
    first_signals = all_signals_data[0][3]
    first_legends = all_signals_data[0][4]

    # Determine number of streams
    sig_data = first_signals['sig']
    if not isinstance(sig_data, list):
        sig_data = [sig_data]
    num_streams = len(sig_data)

    # Branch: Multiple labels require custom plotting with different colors per label
    if len(selected_labels) > 1:
        color_palette = plt.cm.tab10(np.linspace(0, 1, 10))

        # Create subplots - one per stream
        fig, axes = plt.subplots(
            nrows=num_streams, ncols=1, constrained_layout=True, sharex=sharex
        )
        fig.set_size_inches(10, 7, forward=False)
        if num_streams == 1:
            axes = [axes]

        # Plot each stream in its own subplot
        for s_idx in range(num_streams):
            all_plots = []
            all_legends = []

            # Plot each label with a different color
            for idx, (lbl, start_t, end_t, signals, legends) in enumerate(
                all_signals_data
            ):
                sig_data = signals['sig']
                if not isinstance(sig_data, list):
                    sig_data = [sig_data]

                segment_color = color_palette[idx % len(color_palette)]
                stream_data = sig_data[s_idx]

                # Plot all components in this stream
                y_column = 'elapsed_s'
                comps = [k for k in stream_data.dtype.names if k != y_column]

                for c in comps:
                    plot_color_value = plot_color if plot_color else segment_color
                    (plot,) = axes[s_idx].plot(
                        stream_data[y_column],
                        stream_data[c],
                        style,
                        color=plot_color_value,
                    )
                    all_plots.append(plot)
                    all_legends.append(f"{legends['sig'][s_idx]} [{lbl}]")

            # Format subplot
            axes[s_idx].legend(
                all_plots, all_legends, frameon=False, loc=legend_location
            )
            format_subplot(axes[s_idx])

        if plot_title:
            plt.suptitle(plot_title, fontsize=16, fontweight='bold')
        plt.tight_layout()
        plt.show()

    # Branch: Single label uses existing configurable_plot function
    else:
        stims = triggers.compute_stims(npz, actions, times=label_times[0])
        tools.configurable_plot(
            first_signals['sig'],
            leg_contents=first_legends['sig'],
            title=plot_title,
            xlabel=plot_xlabel,
            ylabel=plot_ylabel,
            ylim=[ylim_min.value, ylim_max.value],
            color=plot_color if plot_color else None,
            style=style,
            ncols=plot_ncols,
            same_plot=plot_on_same,
            legend_loc=legend_location,
            sharex=sharex,
            shades=stims,
        )

    # Show filter plots (RMS and FFT) for first label
    if filter_plots_toggle:
        tools.simple_plot(
            first_signals['rms'],
            leg_contents=first_legends['rms'],
            title='RMS Signal - Filter: %s, Window: %.0d' % (filt, rms),
        )
        tools.simple_plot(
            first_signals['fft'],
            y_column='Hz',
            leg_contents=first_legends['fft'],
            title='FFT -  Filter: %s, FFT: %s' % (filt, fft),
        )

# %%
# print out segments table
pd.DataFrame(npz['segments'])

# %%
# print out any saved impedance values
tools.stream_impedances(npz)

# %%
# print out regs
for device, regs in regs_dict.items():
    print(device)
    display(regs)
